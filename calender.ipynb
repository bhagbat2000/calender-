# %%
"""Created on Tue Apr 14 11:52:24 2020

@author: Bhagabat
"""
import calendar
def check_leap(year):
    if(year%100 ==0):
        if(year%400 == 0):
            return True
        else:
            return False
    else:
        if(year%4==0):
            return True
        else:
            return False


def get_day(day_index):
    list_of_days=['Monday','Tuesday','Wednessday','Thursday','Friday','Saturday','Sunday']
    return list_of_days[day_index]

        
def check_valid_date(dt,m,y,l):
    if l:
        if(m==2):
            if dt<30:
                return True
            else:
                return False
        else:
            if m<8:
                if m%2==1:
                    if dt<32:
                        return True
                    else:
                        return False
                else:
                    if dt<31:
                        return True
                    else:
                        return False
            else:
                if m%2==0:
                    if dt<31:
                        return True
                    else:
                        return False
                else:
                    if dt<32:
                        return True
                    else:
                        return False
    else:
        if(m==2):
            if dt<29:
                return True
            else:
                return False
        else:
            if m<8:
                if m%2==1:
                    if dt<32:
                        return True
                    else:
                        return False
                else:
                    if dt<31:
                        return True
                    else:
                        return False
            else:
                if m%2==0:
                    if dt<31:
                        return True
                    else:
                        return False
                else:
                    if dt<32:
                        return True
                    else:
                        return False
                    

         
            

while(1):
    year=int(input("enter any year after 1970"))
    if(year<1970):
        print("enter a valid year")
    else:
        break

while(1):
    month=int(input("enter any month after 1- 12"))
    if(month<=12 and month>0):
        break
        
    else:
        print("enter a valid month")

leap=check_leap(year)

while(1):
    date=int(input("enter any date after 1- 30"))
    if date>0 and check_valid_date(date,month,year,leap):
        break
        
    else:
        print("enter a valid date")
        
day_index=calendar.weekday(year,month,date)
day=get_day(day_index)
print(date,"/",month,"/",year,"falls on ",day)
# Out:
# enter any year after 19702000
# enter any month after 1- 1209
# enter any date after 1- 3013
# 13 / 9 / 2000 falls on  Wednessday
